# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>My Personal Homepage</title>
    <style>
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            margin: 0;
            padding: 0;
            background: #f5f5f5;
            color: #333;
        }
        header {
            background-color: #0077b6;
            color: white;
            padding: 20px 0;
            text-align: center;
        }
        .container {
            padding: 20px;
            max-width: 800px;
            margin: auto;
            background: white;
            margin-top: 30px;
            box-shadow: 0 0 10px rgba(0,0,0,0.1);
        }
        h1 {
            margin-bottom: 10px;
        }
        .bio {
            font-size: 18px;
              line-height: 1.6;
        }
        .social-links a {
            margin-right: 15px;
            text-decoration: none;
            color: #0077b6;
            font-weight: bold;
        }
        footer {
            text-align: center;
            padding: 15px;
            margin-top: 30px;
            background-color: #eee;
        }
    </style>
</head>
<body>
    <header>
        <h1>Your Name</h1>
        <p>Web Development Intern | Passionate Learner</p>
    </header>

    <div class="container">
        <section class="bio">
            <h2>About Me</h2>
            <p>Hello! I'm a web development intern at Hunar Intern. I am passionate about creating websites, learning new technologies, and buildinguser-friendly web experiences. This is my first personal homepage, built using basic HTML and CSS.</p>
        </section>

        <section class="social-links">
            <h2>Connect with Me</h2>
            <a href="https://www.linkedin.com/in/yourprofile" target="_blank">LinkedIn</a>
            <a href="https://github.com/yourusername" target="_blank">GitHub</a>
            <a href="mailto:youremail@example.com">Email</a>
        </section>
    </div>

    <footer>
        &copy; 2025 Your Name. All rights reserved.
    </footer>
</body>
</html>
# Out:
#   Cell In[1], line 17
#     padding: 20px 0;
#               ^
# SyntaxError: invalid decimal literal

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>My Personal Homepage</title>
    <style>
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            margin: 0;
            padding: 0;
            background: #f5f5f5;
            color: #333;
        }
        header {
            background-color: #0077b6;
            color: white;
            padding: 20px 0;
            text-align: center;
        }
        .container {
            padding: 20px;
            max-width: 800px;
            margin: auto;
            background: white;
            margin-top: 30px;
            box-shadow: 0 0 10px rgba(0,0,0,0.1);
        }
        h1 {
            margin-bottom: 10px;
        }
        .bio {
            font-size: 18px;
            line-height: 1.6;
        }
        .social-links a {
            margin-right: 15px;
            text-decoration: none;
            color: #0077b6;
            font-weight: bold;
        }
        footer {
            text-align: center;
            padding: 15px;
            margin-top: 30px;
            background-color: #eee;
        }
    </style>
</head>
<body>
    <header>
        <h1>Your Name</h1>
        <p>Web Development Intern | Passionate Learner</p>
    </header>

    <div class="container">
        <section class="bio">
            <h2>About Me</h2>
            <p>Hello! I'm a web development intern at Hunar Intern. I am passionate about creating websites, learning new technologies, and building user-friendly web experiences. This is my first personal homepage, builtusing basic HTML and CSS.</p>
        </section>

        <section class="social-links">
            <h2>Connect with Me</h2>
            <a href="https://www.linkedin.com/in/yourprofile" target="_blank">LinkedIn</a>
            <a href="https://github.com/yourusername" target="_blank">GitHub</a>
            <a href="mailto:youremail@example.com">Email</a>
        </section>
    </div>

    <footer>
        &copy; 2025 Your Name. All rights reserved.
    </footer>
</body>
</html>
# Out:
#   Cell In[2], line 17
#     padding: 20px 0;
#               ^
# SyntaxError: invalid decimal literal

# %%
from IPython.core.display import display, HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
    <title>My Personal Homepage</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background-color: #f3f3f3;
            color: #333;
            margin: 40px;
            padding: 20px;
            border-radius: 10px;
        }
        .container {
            background: white;
            padding: 30px;
            border-radius: 15px;
            box-shadow: 0 0 15px rgba(0,0,0,0.1);
            max-width: 700px;
            margin: auto;
        }
        h1 {
            color: #0066cc;
        }
        a {
            color: #ff6600;
            text-decoration: none;
        }
        a:hover {
            text-decoration: underline;
        }
        .social {
            margin-top: 20px;
        }
    </style>
</head>
<body>
    <div class="container">
        <h1>Hello! I'm Monesha Palagani</h1>
        <p>Welcome to my personal homepage. I'm an aspiring web developer passionate about learning new technologies and building web applications. I'm currently doing a web development internship with Hunar Intern.</p>

        <div class="social">
            <h3>Contact Me</h3>
            <ul>
                <li><a href="https://www.linkedin.com/in/yourprofile" target="_blank">LinkedIn</a></li>
                <li><a href="mailto:moneshapalagani@gmailo.com">Email Me</a></li>
                <li><a href="https://github.com/dashboard" target="_blank">GitHub</a></li>
            </ul>
        </div>
    </div>
</body>
</html>
"""

# Display in Jupyter Notebook
display(HTML(html_code))
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_400\2668165873.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <!DOCTYPE html>
# <html>
# <head>
#     <title>My Personal Homepage</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #f3f3f3;
#             color: #333;
#             margin: 40px;
#             padding: 20px;
#             border-radius: 10px;
#         }
#         .container {
#             background: white;
#             padding: 30px;
#             border-radius: 15px;
#             box-shadow: 0 0 15px rgba(0,0,0,0.1);
#             max-width: 700px;
#             margin: auto;
#         }
#         h1 {
#             color: #0066cc;
#         }
#         a {
#             color: #ff6600;
#             text-decoration: none;
#         }
#         a:hover {
# ...
